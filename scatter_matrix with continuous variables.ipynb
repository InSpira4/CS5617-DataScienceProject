# %%
#Descriptive Analysis for continuos variables

#CPT is a treatment code which will get accepted or not

#CarrierCode
#FinancialClass
#NPI
#OrderingClinic
#DeniedCode

import pandas as pd

# %matplotlib inline

# %%
claimsdf = pd.read_csv('processedData.csv', index_col=0);
print(claimsdf.columns)
claimsdf.head(2)
# Out:
# Index(['DateOfService', 'CarrierCode', 'Charges', 'Payments',
#        'InsurancePayment', 'PatientPayment', 'Writeoffs', 'InsuranceBal',
#        'PatientBal', 'AllowedAmount', 'FinancialClass', 'CPT', 'DateOfEntry',
#        'PaymentPostDate', 'NPI', 'OrderingClinic', 'DeniedCode',
#        'FirstBilledDate', 'ProviderProfile', 'CaseCount', 'accepted'],
#       dtype='object')
#               DateOfService CarrierCode  Charges  Payments  InsurancePayment  \
# Ticket Number
# 104452             1/2/2019     CFHP-E2     3900       0.0               0.0
# 104453             1/2/2019     CFHP-E2     3900       0.0               0.0
#
#                PatientPayment  Writeoffs  InsuranceBal  PatientBal  \
# Ticket Number
# 104452                    0.0        0.0           0.0      3900.0
# 104453                    0.0        0.0           0.0      3900.0
#
#                AllowedAmount  ...    CPT DateOfEntry PaymentPostDate  \
# Ticket Number                 ...
# ...

# %%
claimsdf.shape
# Out:
# (22696, 21)

# %%
claimsdf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 22696 entries, 104452 to 407677
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   DateOfService     22696 non-null  object
#  1   CarrierCode       22696 non-null  object
#  2   Charges           22696 non-null  int64
#  3   Payments          22696 non-null  float64
#  4   InsurancePayment  22696 non-null  float64
#  5   PatientPayment    22696 non-null  float64
#  6   Writeoffs         22696 non-null  float64
#  7   InsuranceBal      22696 non-null  float64
#  8   PatientBal        22696 non-null  float64
#  9   AllowedAmount     22696 non-null  float64
#  10  FinancialClass    22696 non-null  object
#  11  CPT               22696 non-null  object
#  12  DateOfEntry       22696 non-null  object
#  13  PaymentPostDate   22696 non-null  object
#  14  NPI               22696 non-null  int64
#  15  OrderingClinic    22690 non-null  object
# ...

# %%
from pandas.plotting import scatter_matrix
# pd.scatter_matrix(claimsdf.loc[:, 'CPT':'FinancialClass'])

# %%
scatter_matrix(claimsdf.loc[:, 'Charges':'PatientPayment'], figsize = (20,15), diagonal='kde')
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000001F13C5CFF08>,
# ...
#       dtype=object)

# %%
scatter_matrix(claimsdf.loc[:, 'Writeoffs':'AllowedAmount'], figsize = (20,15), diagonal='kde')
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000001F13DF8C1C8>,
# ...
#       dtype=object)
